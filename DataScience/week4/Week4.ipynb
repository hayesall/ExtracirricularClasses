# %% [markdown]
# # Week 4: Important Python Libraries for Data Analysis
# Alexander L. Hayes
# Alexander.Hayes@utdallas.edu
#
# ### Previously...
# We had an in-depth introduction to Python and downloaded a dataset for Google's stock prices.

# %%
# Demo of the nltk library

"""
From a console:
>>> import nltk
>>> nltk.download()

Download punkt
"""

from nltk.tokenize import word_tokenize

data = "All work and no play makes Jack a dull boy, all work and no play makes Jack a dull boy,"
print(word_tokenize(data))
# Out:
# ['All', 'work', 'and', 'no', 'play', 'makes', 'Jack', 'a', 'dull', 'boy', ',', 'all', 'work', 'and', 'no', 'play', 'makes', 'Jack', 'a', 'dull', 'boy', ',']

# %%
# Brief numpy demo:
import numpy as np
x = np.array([[1, 2], [3, 4]])

print("An array for demonstration:")
print(x)
print("The sum of all elements:", np.sum(x))
print("The sum of each column: ", np.sum(x, axis=0))
print("The sum of each row:    ", np.sum(x, axis=1))

a = np.array([1, 2, 3])
print("Another array for demonstration:")
print(a)
print("What is the type this array?", type(a))
print("What is the array's shape?  ", a.shape)
print("Individual elements in the array:")
print("       ", a[0], a[1], a[2])
# Out:
# An array for demonstration:
# [[1 2]
#  [3 4]]
# The sum of all elements: 10
# The sum of each column:  [4 6]
# The sum of each row:     [3 7]
# Another array for demonstration:
# [1 2 3]
# What is the type this array? <class 'numpy.ndarray'>
# What is the array's shape?   (3,)
# Individual elements in the array:
#         1 2 3

# %%
# Numpy for calculating euclidean distance:
# import numpy as np # This was already imported earlier:
from scipy.spatial.distance import pdist, squareform

x = np.array([[0, 1], [1, 0], [2, 0]])
print(x)

# Find the geometric distance between all points:
d = squareform(pdist(x, 'euclidean'))
print(d)
# Out:
# [[0 1]
#  [1 0]
#  [2 0]]
# [[ 0.          1.41421356  2.23606798]
#  [ 1.41421356  0.          1.        ]
#  [ 2.23606798  1.          0.        ]]

# %%
# import numpy as np
b = np.array([[1, 2, 3], [4, 5, 6]])
# b is a 2x3 matrix:
print(b.shape)
# These are printing the coordinates of points:
print(b[0, 0], b[0, 1], b[1, 0])
# Out:
# (2, 3)
# 1 2 4

# %%
# numpy with matplotlib
import matplotlib.pyplot as plt
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

print("Contents of x array:", str(x[0:5]).replace(']', ', ... ]'))
print("Contents of y array:", str(y[0:5]).replace(']', ', ... ]'))

# Plot the points using matploblib
plt.plot(x, y)
plt.show()
# Out:
# Contents of x array: [ 0.   0.1  0.2  0.3  0.4, ... ]
# Contents of y array: [ 0.          0.09983342  0.19866933  0.29552021  0.38941834, ... ]

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])
plt.show()

# %%
# import numpy as np
from scipy.misc import imread, imresize
# import matplotlib.pyplot as plt
img = imread('cat.jpg')
img_tinted = img * [1, 0.95, 0.9]
plt.titl
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.subplot(1, 2, 2)
plt.imshow(np.uint8(img_tinted))
plt.show()

# %%
# Pandas!
# pandas is a Python package providing fast, flexible, and expressive data structures designed to
# make working with Relational or Labeled data easier.

# Series (1-dimensional), DataFrame (2-dimensional)

import pandas as pd
